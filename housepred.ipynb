# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/ryan/Downloads/kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.displot(df['price'])

# %%
df.select_dtypes(include='number').corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(x='price',y='sqft_living',data=df,c='red')

# %%
sns.histplot(df['sqft_living'])
# Out:
# <Axes: xlabel='sqft_living', ylabel='Count'>

# %%
df.groupby('zipcode')['sqft_living'].mean()
# Out:
# zipcode
# 98001    1900.856354
# 98002    1627.743719
# 98003    1928.882143
# 98004    2909.022082
# 98005    2656.803571
#             ...
# 98177    2323.333333
# 98178    1729.351145
# 98188    1802.772059
# 98198    1745.360714
# 98199    2161.798107
# Name: sqft_living, Length: 70, dtype: float64

# %%
sns.scatterplot(x='long',y='lat',data=df,hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df.drop(columns=['id'],inplace=True)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].apply(lambda x: x.year)

# %%
df['month'] = df['date'].apply(lambda x: x.month)

# %%
df.corr()['price']
# Out:
# date            -0.004357
# price            1.000000
# bedrooms         0.308350
# bathrooms        0.525138
# sqft_living      0.702035
# sqft_lot         0.089661
# floors           0.256794
# waterfront       0.266369
# view             0.397293
# condition        0.036362
# grade            0.667434
# sqft_above       0.605567
# sqft_basement    0.323816
# yr_built         0.054012
# yr_renovated     0.126434
# zipcode         -0.053203
# lat              0.307003
# long             0.021626
# sqft_living15    0.585379
# sqft_lot15       0.082447
# year             0.003576
# month           -0.010081
# Name: price, dtype: float64

# %%
df.groupby('month')['price'].mean()
# Out:
# month
# 1     525870.889571
# 2     507851.371200
# 3     543977.187200
# 4     561837.774989
# 5     550768.785833
# 6     558002.199541
# 7     544788.764360
# 8     536445.276804
# 9     529253.821871
# 10    539026.971778
# 11    521961.009213
# 12    524461.866757
# Name: price, dtype: float64

# %%
df.drop(columns=['zipcode'],inplace=True)

# %%
df.drop(columns=['date'],inplace=True)

# %%
df['renovated'] = np.where(df['yr_renovated'] > 0,1,0)

# %%
df['renovated'].value_counts()
# Out:
# renovated
# 0    20699
# 1      914
# Name: count, dtype: int64

# %%
X = df.drop('price',axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
# !pip3 install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 18.1 MB/s eta 0:00:00a 0:00:01
# Using cached protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.2
#     Uninstalling protobuf-4.21.2:
#       Successfully uninstalled protobuf-4.21.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.2
#     Uninstalling numpy-1.23.2:
#       Successfully uninstalled numpy-1.23.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# brscraper 1.0.1 requires pytz>=2023.3, but you have pytz 2022.7.1 which is incompatible.
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

# %%
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 5ms/step - loss: 423595016192.0000 - val_loss: 432737976320.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 2ms/step - loss: 410245824512.0000 - val_loss: 369267736576.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 197082660864.0000 - val_loss: 88630403072.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 3ms/step - loss: 75981946880.0000 - val_loss: 61379231744.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 59924541440.0000 - val_loss: 53739540480.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 53891502080.0000 - val_loss: 49329655808.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 49759911936.0000 - val_loss: 46078824448.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
preds = model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 1ms/step

# %%
mean_absolute_error(y_test,preds)
# Out:
# 97477.11012082627

# %%
mean_squared_error(y_test,preds)
# Out:
# 25348446320.68212

# %%
np.sqrt(mean_squared_error(y_test,preds))
# Out:
# 159211.9540759491

# %%
explained_variance_score(y_test,preds)
# Out:
# 0.8193109922724426

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(x=y_test,y=preds)

# %%
df.drop('price',axis=1).iloc[0]
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# year             2014.0000
# month              10.0000
# renovated           0.0000
# Name: 0, dtype: float64

# %%
singlehouse = df.drop('price',axis=1).iloc[0]

# %%
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#          5.65000e+03,  2.01400e+03,  1.00000e+01,  0.00000e+00]])

# %%
singlehouse = scaler.transform(singlehouse.values.reshape(-1,20))

# %%
model.predict(singlehouse)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# array([[267207.8]], dtype=float32)

# %%
df['price'].max()
# Out:
# 7700000.0

# %%
df['price'].min()
# Out:
# 75000.0

# %%
df.sort_values(by='price',ascending=False)
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7252   7700000.0         6       8.00        12050     27600     2.5
# 3914   7062500.0         5       4.50        10040     37325     2.0
# 9254   6885000.0         6       7.75         9890     31374     2.0
# 4411   5570000.0         5       5.75         9200     35069     2.0
# 1448   5350000.0         5       5.00         8000     23985     2.0
# ...          ...       ...        ...          ...       ...     ...
# 8274     82000.0         3       1.00          860     10426     1.0
# 16198    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15293    78000.0         2       1.00          780     16344     1.0
# 1149     75000.0         1       0.00          670     43377     1.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# ...
